# %%
from llama_cloud_services import LlamaParse

parser = LlamaParse(
    api_key="",
    language="bn",
    parse_mode="parse_document_with_agent",
)

result = parser.parse("../data/raw/HSC26-Bangla1st-Paper.pdf")
# Out:
# Started parsing the file under job_id e81ab9b0-a5e1-4042-a95c-e50c246cef24
# .........

# %%
markdown_documents = result.get_markdown_documents(split_by_page=False)
# Out:
# <bound method JobResult.get_markdown of JobResult(pages=[Page(page=1, text='    [$৫26\n    অনলাইন ব্যাচ\n    বাংলা ইংরেজি * আইসিটি\n\n    িাাং    া\n    ১ম পত্র\n\nআল ািয রিষয়\n\n  অপরিরিতা\n\n\n    অনলাইনব্ যাচ সম্পর্কত যেককাকনা জি  াসা  ,\n    কল করৌ  16910', md='\n# 10 MINUTE SCHOOL\n\n## HSC 26\n## অনলাইন ব্যাচ\n## বাংলা • ইংরেজি • আইসিটি\n\n### বাংলা\n### ১ম পত্র\n\n#### আলোচ্য বিষয়\n\n**অপরিচিতা**\n\nঅনলাইন ব্যাচ সম্পর্কিত যেকোনো জিজ্ঞাসা,  \nকল করো ☎ 16910', images=[ImageItem(name='img_p0_1.png', height=1536.0, width=1063.0, x=0.0, y=0.0, original_width=1063, original_height=1536, type=None), ImageItem(name='img_p0_2.png', height=89.0, width=555.0, x=178.92, y=657.84, original_width=555, original_height=89, type=None), ImageItem(name='img_p0_3.png', height=296.0, width=698.0, x=144.24, y=172.2, original_width=698, original_height=296, type=None), ImageItem(name='page_1.jpg', height=780.0, width=540.0, x=0.0, y=0.0, original_width=1108, original_height=1600, type='full_page_screenshot')], charts=[], tables=[], layout=[], items=[PageItem(type='heading', lvl=1, value='10 MINUTE SCHOOL', md='# 10 MINUTE SCHOOL', rows=None, bBox=BBox(x=0.0, y=0.0, w=540.0, h=780.0)), PageItem(type='heading', lvl=2, value='HSC 26', md='## HSC 26', rows=None, bBox=BBox(x=0.0, y=0.0, w=540.0, h=780.0)), PageItem(type='heading', lvl=2, value='অনলাইন ব্যাচ', md='## অনলাইন ব্যাচ', rows=None, bBox=BBox(x=144.0, y=207.0, w=240.0, h=171.49)), PageItem(type='heading', lvl=2, value='বাংলা • ইংরেজি • আইসিটি', md='## বাংলা • ইংরেজি • আইসিটি', rows=None, bBox=BBox(x=310.43, y=334.49, w=13.0, h=44.0)), PageItem(type='heading', lvl=3, value='বাংলা', md='### বাংলা', rows=None, bBox=BBox(x=310.43, y=334.49, w=13.0, h=44.0)), PageItem(type='heading', lvl=3, value='১ম পত্র', md='### ১ম পত্র', rows=None, bBox=BBox(x=223.18, y=385.56, w=70.3, h=32.0)), PageItem(type='heading', lvl=4, value='আলোচ্য বিষয়', md='#### আলোচ্য বিষয়', rows=None, bBox=BBox(x=0.0, y=0.0, w=540.0, h=780.0)), PageItem(type='text', lvl=None, value='**অপরিচিতা**\n\nঅনলাইন ব্যাচ সম্পর্কিত যেকোনো জিজ্ঞাসা,  \nকল করো ☎ 16910', md='**অপরিচিতা**\n\nঅনলাইন ব্যাচ সম্পর্কিত যেকোনো জিজ্ঞাসা,  \nকল করো ☎ 16910', rows=None, bBox=BBox(x=144.0, y=207.0, w=240.0, h=478.0))], status='OK', links=[], width=540.0, height=780.0, triggeredAutoMode=False, parsingMode='continuous-agent', structuredData=None, noStructuredContent=False, noTextContent=False), Page(page=2, text="               িখন ফল\n\n     ✓ নম্নর্ব্ি    যজক্তি    হঠাৎ িিালী      হক ওঠাি ফকল সমাকি পর্িচ                        সংকট সম্পকক    ধািণা লাভ কিকব্।\n     ✓ তৎকালীন সমাি-সভযতা ও মানব্তাি             অব্মাননা            সম্পকক          িানকত পািকব্।\n     ✓ তৎকালীন সমাকিি পণপ্রথাি               কুপ্রভাব্  সম্পকক   িানকত পািকব্।\n     ✓ তৎকাকল সমাকি ভদ্রকলাককি            ভাব্বব্র্িষ্ট্য    সম্পকক              ানলাভ  কিকব্।\n     ✓ নািী যকামল ঠিক, কন্তু          দুব্িল  ন - কলযাণীি িীব্নচর্িত                    ািা    তজিত  এই সতয অনুধাব্ন                কিকত\n               পািকব্।\n     ✓ মানুষ          আিা নক   যব্ঁকচ  থাকক-     অনুপকমি        দৃষ্ট্াকন্ত      মানব্িীব্কনি  এই চিন্তন          সতযদিিন           সম্পকক\n               ানলাভ  কিকব্।\n\n               াক     -মূলযা  ন\n\n    ১। অনুপলেি িািা কী কলি জীরিকা রনিবাহ কিলতন?\n    ক) ডাক্তার্ি               খ) ওকালর্ত                       গ) মাস্টার্ি                        ঘ) যব্সা\n    ২। োোলক ভাগ্য দেিতািপ্র ধান এলজন্ট ি       াি কািণ                       , তাি-\n    ক) তপজি                    খ) ভাব্                          গ) চক্ষণতা                          ঘ) কূটব্ুর্ ি\n    নকচি অনুকেদটি পক়ে         ৩ ও ৪             $৫|00|\n                                       সংখযকপ্র কেি উিি দাও।\n    পতৃহীন দীপুি চাচাইর্ িকলন পর্িব্াকিি কতিা। দীপুর্ িজক্ষত হকলও তাির্ সিান্ত যনও             া            িক্ষ মতার্ িল না। চাচা\n    তাির্ব্ ক  ি উকদযাগর্ নকলও যেৌতুকর্ নকব্  া়োব্ার়্ে কিাি কািকণ কনযাির্ পতা অপমার্ন                         ত যব্াধ ককির্ব্ ক  ি\n    আকলাচনা যভকে যদন। দী ...
