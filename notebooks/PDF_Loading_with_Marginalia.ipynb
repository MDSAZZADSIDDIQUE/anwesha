# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from agentic_doc.parse import parse
# Out:
# 2025-07-24 20:25:41 [info   ] Settings loaded: {
#   "endpoint_host": "https://api.va.landing.ai",
#   "vision_agent_api_key": "dXJnM[REDACTED]",
#   "batch_size": 4,
#   "max_workers": 5,
#   "max_retries": 100,
#   "max_retry_wait_time": 60,
#   "retry_logging_style": "log_msg",
#   "pdf_to_image_dpi": 96,
#   "split_size": 10,
#   "extraction_split_size": 50
# } [agentic_doc.config] (config.py:170)

# %%
result = parse("../data/raw/HSC26-Bangla1st-Paper.pdf")
# Out:
# 2025-07-24 20:26:15 [info   ] API key is valid.              [agentic_doc.utils] (utils.py:42)
# 2025-07-24 20:26:15 [info   ] Parsing 1 documents            [agentic_doc.parse] (parse.py:280)
# 2025-07-24 20:26:15 [info   ] Splitting PDF: '..\data\raw\HSC26-Bangla1st-Paper.pdf' into 4 parts under 'C:\Users\mdsaz\AppData\Local\Temp\tmpzq9tetpe' [agentic_doc.utils] (utils.py:236)
# Parsing documents:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-07-24 20:26:15 [info   ] Created C:\Users\mdsaz\AppData\Local\Temp\tmpzq9tetpe\HSC26-Bangla1st-Paper_1.pdf [agentic_doc.utils] (utils.py:252)
# 2025-07-24 20:26:15 [info   ] Created C:\Users\mdsaz\AppData\Local\Temp\tmpzq9tetpe\HSC26-Bangla1st-Paper_2.pdf [agentic_doc.utils] (utils.py:252)
# 2025-07-24 20:26:15 [info   ] Created C:\Users\mdsaz\AppData\Local\Temp\tmpzq9tetpe\HSC26-Bangla1st-Paper_3.pdf [agentic_doc.utils] (utils.py:252)
# 2025-07-24 20:26:15 [info   ] Created C:\Users\mdsaz\AppData\Local\Temp\tmpzq9tetpe\HSC26-Bangla1st-Paper_4.pdf [agentic_doc.utils] (utils.py:252)
# 2025-07-24 20:26:15 [info   ] Created C:\Users\mdsaz\AppData\Local\Temp\tmpzq9tetpe\HSC26-Bangla1st-Paper_5.pdf [agentic_doc.utils] (utils.py:252)
# 2025-07-24 20:26:15 [info   ] Start parsing document part: 'File name: HSC26-Bangla1st-Paper_1.pdf	Page: [0:9]'
#  [agentic_doc.parse]
# Parsing document parts from 'HSC26-Bangla1st-Paper.pdf':   0%|          | 0/5 [00:00<?, ?it/s]
#  (parse.py:670)
# 2025-07-24 20:26:15 [info   ] Start parsing document part: 'File name: HSC26-Bangla1st-Paper_2.pdf	Page: [10:19]' [agentic_doc.parse] (parse.py:670)
# 2025-07-24 20:26:15 [info   ] Start parsing document part: 'File name: HSC26-Bangla1st-Paper_3.pdf	Page: [20:29]' [agentic_doc.parse] (parse.py:670)
# 2025-07-24 20:26:15 [info   ] Start parsing document part: 'File name: HSC26-Bangla1st-Paper_4.pdf	Page: [30:39]' [agentic_doc.parse] (parse.py:670)
# 2025-07-24 20:26:15 [info   ] Start parsing document part: 'File name: HSC26-Bangla1st-Paper_5.pdf	Page: [40:48]' [agentic_doc.parse] (parse.py:670)
# HTTP Request: POST https://api.va.landing.ai/v1/tools/agentic-document-analysis "HTTP/1.1 200 OK" (_client.py:1025)
# 2025-07-24 20:26:37 [info   ] Time taken to successfully parse a document chunk: 21.83 seconds [agentic_doc.parse] (parse.py:823)
# 2025-07-24 20:26:37 [info   ] Successfully parsed document part: 'File name: HSC26-Bangla1st-Paper_4.pdf	Page: [30:39]' [agentic_doc.parse] (parse.py:679)
# HTTP Request: POST https://api.va.landing.ai/v1/tools/agentic-document-analysis "HTTP/1.1 200 OK" (_client.py:1025)
# 2025-07-24 20:26:45 [info   ] Time taken to successfully parse a document chunk: 29.29 seconds [agentic_doc.parse] (parse.py:823)
# 2025-07-24 20:26:45 [info   ] Successfully parsed document part: 'File name: HSC26-Bangla1st-Paper_3.pdf	Page: [20:29]' [agentic_doc.parse] (parse.py:679)
# HTTP Request: POST https://api.va.landing.ai/v1/tools/agentic-document-analysis "HTTP/1.1 200 OK" (_client.py:1025)
# 2025-07-24 20:26:50 [info   ] Time taken to successfully parse a document chunk: 34.55 seconds [agentic_doc.parse] (parse.py:823)
# 2025-07-24 20:26:50 [info   ] Successfully parsed document part: 'File name: HSC26-Bangla1st-Paper_5.pdf	Page: [40:48]' [agentic_doc.parse] (parse.py:679)
# HTTP Request: POST https://api.va.landing.ai/v1/tools/agentic-document-analysis "HTTP/1.1 200 OK" (_client.py:1025)
# 2025-07-24 20:27:06 [info   ] Time taken to successfully parse a document chunk: 50.53 seconds [agentic_doc.parse] (parse.py:823)
# 2025-07-24 20:27:06 [info   ] Successfully parsed document part: 'File name: HSC26-Bangla1st-Paper_1.pdf	Page: [0:9]' [agentic_doc.parse] (parse.py:679)
# Parsing document parts from 'HSC26-Bangla1st-Paper.pdf':  20%|██        | 1/5 [00:50<03:22, 50.55s/it]
# HTTP Request: POST https://api.va.landing.ai/v1/tools/agentic-document-analysis "HTTP/1.1 200 OK" (_client.py:1025)
# 2025-07-24 20:27:10 [info   ] Time taken to successfully parse a document chunk: 54.41 seconds [agentic_doc.parse] (parse.py:823)
# 2025-07-24 20:27:10 [info   ] Successfully parsed document part: 'File name: HSC26-Bangla1st-Paper_2.pdf	Page: [10:19]' [agentic_doc.parse] (parse.py:679)
# Parsing document parts from 'HSC26-Bangla1st-Paper.pdf': 100%|██████████| 5/5 [00:54<00:00, 10.89s/it]
# Parsing documents: 100%|██████████| 1/1 [00:54<00:00, 54.64s/it]

# %%
parsed_doc = result[0]

# %%
parsed_doc
# Out:
# ParsedDocument(markdown='Summary : This image is a logo for "10 Minute School", featuring stylized text and a graphic element.\n\nlogo: 10 Minute School\n\nVisible Elements :\n  • The number "10" is prominently displayed on the left, with the "0" partially encircled by a red arrow forming the upper right quadrant.\n  • The words "MINUTE SCHOOL" appear in uppercase, stacked to the right of the "10".\n  • "MINUTE" is on the top line, "SCHOOL" is directly below it.\n  • All text is in a clean, sans-serif font.\n  • The red arrow within the "0" points upward and to the right, suggesting movement or progress.\n\nDimensions & Placement :\n  • The "10" is larger and bolder than the text to its right.\n  • The red arrow is integrated into the "0" and is the only colored element, drawing attention.\n\nAnalysis :\n  • The logo uses a minimalistic design with a single accent color (red) to highlight the concept of time (the arrow in the "0") and learning efficiency (the "10 Minute" theme).\n  • The overall composition is balanced, with the bold "10" anchoring the left and the stacked text providing clarity. <!-- figure, from page 0 (l=0.403,t=0.133,r=0.599,b=0.182), with ID 547ece11-7cb9-4af2-ba9a-1a08eefd5f0b -->\n\nSummary : This image is a logo and promotional banner for an online batch program targeting HSC 2026 students, offering courses in Bangla, English, and ICT.\n\nlogo: HSC 26 Online Batch (অনলাইন ব্যাচ)\n  Main Text Elements :\n    • "HSC 26" in bold white text on a red background.\n    • "অনলাইন ব্যাচ" (Online Batch in Bengali) in large black text with a stylized wireless signal icon.\n    • "বাংলা · ইংরেজি · আইসিটি" (Bangla · English · ICT) in white text on a red background.\n  Design & Layout :\n    • Rectangular red and white color blocks.\n    • Black and white text for contrast and emphasis.\n    • Wireless signal icon to suggest online/remote learning.\n    • All text is centered and uses bold, sans-serif fonts.\n  Dimensions & Placement :\n    • "HSC 26" at the top, "অনলাইন ব্যাচ" in the middle, and subject list at the bottom.\n    • Each section is separated by color blocks for clear visual hierarchy.\n  Analysis :\n    • The logo uses red, black, and white for high visibility and urgency, targeting students preparing for the HSC 2026 exam.\n    • The inclusion of subject names and the wireless icon emphasizes the online, multi-subject nature of the batch. <!-- figure, from page 0 (l=0.255,t=0.212,r=0.745,b=0.364), with ID cd88ae2c-cc04-494f-b5d3-481d7d23727b -->\n\nবাংলা\n১ম পত্র <!-- text, from page 0 (l=0.384,t=0.436,r=0.614,b=0.544), with ID d9131ddd-b9f7-4053-9fd6-3fbe249690c2 -->\n\nআলোচ্য বিষয়\n\nঅপরিচিতা <!-- text, from page 0 (l=0.216,t=0.617,r=0.784,b=0.714), with ID 8ad309e5-6daf-4f75-9cc7-4cc4cafdf326 -->\n\nSummary : This is a call-to-action graphic in Bengali, providing a helpline number for queries related to online banking.\n\nphoto:\nScene Overview :\n  • The image contains Bengali text instructing users to call a helpline for any questions about online banking.\n  • The main visual element is a bold, two-part banner: the left side is black with white Bengali text "কল করো" (Call), and the right side is red with a white phone icon and the number "16910" in large digits.\n  • The overall design is simple, with high contrast to draw attention to the phone number.\n\nTechnical Details :\n  • No scale bar or magnification.\n  • The text is clear and legible.\n  • The phone icon is white on a red background, visually linking it to the helpline number.\n\nSpatial Relationships :\n  • The black "কল করো" box is on the left, the red "16910" box is on the right.\n  • The phone icon is placed immediately before the number, reinforcing the call-to-action.\n\nAnalysis :\n  • The graphic is designed for maximum visibility and clarity, making it easy for users to find and dial the helpline number for online banking support.\n  • The use of contrasting colours and large font size ensures the information stands out. < ...

# %%
parsed_doc.chunks
# Out:
# [Chunk(text='Summary : This image is a logo for "10 Minute School", featuring stylized text and a graphic element.\n\nlogo: 10 Minute School\n\nVisible Elements :\n  • The number "10" is prominently displayed on the left, with the "0" partially encircled by a red arrow forming the upper right quadrant.\n  • The words "MINUTE SCHOOL" appear in uppercase, stacked to the right of the "10".\n  • "MINUTE" is on the top line, "SCHOOL" is directly below it.\n  • All text is in a clean, sans-serif font.\n  • The red arrow within the "0" points upward and to the right, suggesting movement or progress.\n\nDimensions & Placement :\n  • The "10" is larger and bolder than the text to its right.\n  • The red arrow is integrated into the "0" and is the only colored element, drawing attention.\n\nAnalysis :\n  • The logo uses a minimalistic design with a single accent color (red) to highlight the concept of time (the arrow in the "0") and learning efficiency (the "10 Minute" theme).\n  • The overall composition is balanced, with the bold "10" anchoring the left and the stacked text providing clarity.', grounding=[ChunkGrounding(page=0, box=ChunkGroundingBox(l=0.4031754732131958, t=0.13256731629371643, r=0.5990890264511108, b=0.18200168013572693), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='547ece11-7cb9-4af2-ba9a-1a08eefd5f0b'),
#  Chunk(text='Summary : This image is a logo and promotional banner for an online batch program targeting HSC 2026 students, offering courses in Bangla, English, and ICT.\n\nlogo: HSC 26 Online Batch (অনলাইন ব্যাচ)\n  Main Text Elements :\n    • "HSC 26" in bold white text on a red background.\n    • "অনলাইন ব্যাচ" (Online Batch in Bengali) in large black text with a stylized wireless signal icon.\n    • "বাংলা · ইংরেজি · আইসিটি" (Bangla · English · ICT) in white text on a red background.\n  Design & Layout :\n    • Rectangular red and white color blocks.\n    • Black and white text for contrast and emphasis.\n    • Wireless signal icon to suggest online/remote learning.\n    • All text is centered and uses bold, sans-serif fonts.\n  Dimensions & Placement :\n    • "HSC 26" at the top, "অনলাইন ব্যাচ" in the middle, and subject list at the bottom.\n    • Each section is separated by color blocks for clear visual hierarchy.\n  Analysis :\n    • The logo uses red, black, and white for high visibility and urgency, targeting students preparing for the HSC 2026 exam.\n    • The inclusion of subject names and the wireless icon emphasizes the online, multi-subject nature of the batch.', grounding=[ChunkGrounding(page=0, box=ChunkGroundingBox(l=0.25541800260543823, t=0.21164187788963318, r=0.7448121905326843, b=0.3642742335796356), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='cd88ae2c-cc04-494f-b5d3-481d7d23727b'),
#  Chunk(text='বাংলা\n১ম পত্র', grounding=[ChunkGrounding(page=0, box=ChunkGroundingBox(l=0.38367971777915955, t=0.43642932176589966, r=0.6144566535949707, b=0.5443140268325806), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='d9131ddd-b9f7-4053-9fd6-3fbe249690c2'),
#  Chunk(text='আলোচ্য বিষয়\n\nঅপরিচিতা', grounding=[ChunkGrounding(page=0, box=ChunkGroundingBox(l=0.2163507342338562, t=0.6171913743019104, r=0.7844224572181702, b=0.7144477963447571), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='8ad309e5-6daf-4f75-9cc7-4cc4cafdf326'),
#  Chunk(text='Summary : This is a call-to-action graphic in Bengali, providing a helpline number for queries related to online banking.\n\nphoto:\nScene Overview :\n  • The image contains Bengali text instructing users to call a helpline for any questions about online banking.\n  • The main visual element is a bold, two-part banner: the left side is black with white Bengali text "কল করো" (Call), and the right side is red with a white phone icon and the number "16910" in large digits.\n  • The overall design is simple, with high contrast to draw attention to the phone number.\n\nTechnical Details :\n  • No scale bar or magnification.\n  • The text is clear and legible.\n  • The phone icon is white on a red background, visually linking it to the helpline number.\n\nSpatial Relationships :\n  • The black "কল করো" box is on the left, the red "16910" box is on the right.\n  • The phone icon is placed immediately before the number, reinforcing the call-to-action.\n\nAnalysis :\n  • The graphic is designed for maximum visibility and clarity, making it easy for users to find and dial the helpline number for online banking support.\n  • The use of contrasting colours and large font size ensures the information stands out.', grounding=[ChunkGrounding(page=0, box=ChunkGroundingBox(l=0.2921850085258484, t=0.813430666923523, r=0.7048825025558472, b=0.886062502861023), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='7655bc11-fbc0-4575-a2d8-1f7e40afa0b2'),
#  Chunk(text='logo: HSC 26 অনলাইন ব্যাচ (Bangla, English, ICT)\nSummary : This is a logo for an online batch program targeting HSC 2026 students, with a focus on Bangla, English, and ICT subjects.\n\nText Elements :\n  • "HSC 26" in bold white text on a red background.\n  • "অনলাইন ব্যাচ" (Online Batch in Bengali) in bold black text.\n  • "বাংলা • ইংরেজি • আইসিটি" (Bangla • English • ICT) in white text on a red background.\n\nDesign Features :\n  • Red and black color scheme.\n  • Wi-Fi signal icon to the right of the main text, indicating online connectivity.\n  • Rectangular blocks for emphasis behind key text elements.\n\nDimensions & Placement :\n  • Horizontal layout with stacked text blocks.\n  • All text is centered and aligned for clarity.\n\nAnalysis : \n  • The logo uses bold colors and clear text to communicate its focus on online education for HSC 2026 students, specifically in Bangla, English, and ICT. The Wi-Fi icon reinforces the online aspect of the program.', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.0639171227812767, t=0.028414489701390266, r=0.20065400004386902, b=0.07406187057495117), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='f27d2f11-e389-4887-88bf-71a6cdcbd8ad'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text : \n  • "10 MINUTE SCHOOL" in uppercase letters.\n  • The "10" is stylized: the "1" is a black vertical bar, and the "0" is a black circle with a red arrow forming part of the zero.\n\nDesign Elements : \n  • The red arrow curves clockwise inside the "0", starting from the left and pointing upward/right.\n  • Font is bold and sans-serif.\n  • The logo is horizontally aligned, with "10" on the left and "MINUTE SCHOOL" stacked on the right.\n\nDimensions & Placement : \n  • "10" is larger and to the left; "MINUTE" is above "SCHOOL" on the right.\n  • The red arrow is the only colored element, drawing attention to the "0".\n\nAnalysis : \n  • The logo uses a bold, modern design with a red arrow to suggest speed or progress, aligning with the "10 Minute" educational theme.', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.8011504411697388, t=0.034646809101104736, r=0.9321705102920532, b=0.06854619830846786), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='b93b0257-0e8e-40cf-8a53-3155d20c7e9d'),
#  Chunk(text='🎯 শিক্ষানফল', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.07100743800401688, t=0.08638240396976471, r=0.24004217982292175, b=0.12399441003799438), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='a0711ce8-a656-4e3a-b911-5417104cc609'),
#  Chunk(text='-  নির্লিপ্ত ব্যক্তির হঠাৎ বিজ্ঞানী হয়ে ওঠার ফলে সমাজে পরিচয় সংকট সম্পর্কে ধারণা লাভ করবে।\n-  তৎকালীন সমাজ-সভ্যতা ও মানবতার অসামান্য সম্পর্কে জানতে পারবে।\n-  তৎকালীন সমাজের পথপ্রদর্শক কুশলতার সম্পর্কে জানতে পারবে।\n-  তৎকালে সমাজে অদ্বৈতবোধের স্বতঃবৈশিষ্ট্য সম্পর্কে জ্ঞানলাভ করবে।\n-  নারী কোমল ঠিক, কিন্তু দুর্বল নয়- কল্যাণীর জীবনচরিত দ্বারা প্রতিষ্ঠিত এই সত্য অনুধাবন করতে পারবে।\n-  মানুষ আশা নিয়ে বেঁচে থাকে- অনুশীলনের দৃষ্টিতে মানবজীবনের এই চিরন্তন সত্যদর্শন সম্পর্কে জ্ঞানলাভ করবে।', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.07419830560684204, t=0.12791144847869873, r=0.9293902516365051, b=0.34708401560783386), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='adca77b5-c2f3-48e1-a7a7-9fc942fa3069'),
#  Chunk(text='প্রাক-মূল্যায়ন', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.06945347785949707, t=0.3568495512008667, r=0.2793779969215393, b=0.39411330223083496), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='c3563601-f67a-4f4d-b4ca-e675335b50df'),
#  Chunk(text='১। অনুপমের বাবা কী করে জীবিকা নির্বাহ করতেন?\nক) ডাক্তারি        খ) ওকালতি        গ) মাস্টারি        ঘ) ব্যবসা\n\n২। মামাকে ভাগ্য দেবতার প্রধান এজেন্ট বলার কারণ, তার-\nক) প্রতিপত্তি        খ) প্রভাব        গ) বিচক্ষণতা        ঘ) কূট বুদ্ধি\n\nনিচের অনুচ্ছেদটি পড়ে ৩ ও ৪ সংক্ষিপ্ত প্রশ্নের উত্তর দাও।\nপিঁপড়িনি দীপুর চাচাই ছিলেন পরিবারের কর্তা। দীপু শিক্ষিত হলেও তার সিদ্ধান্ত নেওয়ার ক্ষমতা ছিল না। চাচা তার বিয়ের উদ্যোগ নিলেও যৌতুক নিয়ে বাড়াবাড়ি করার কারণে কন্যার পিতা অপমানিত বোধ করে বিয়ের আলোচনা ভেঙে দেন। দীপু মেয়েটির ছবি দেখে খুশি হলেও তার চাচাকে কিছুই বলতে পারেননি।', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.06379067897796631, t=0.4003957211971283, r=0.920905351638794, b=0.6002933382987976), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='94b91fda-c797-43a8-85eb-fe82f3d81716'),
#  Chunk(text='৩। দীপুর চাচার সঙ্গে ‘অপরিচিতা’ গল্পের কোন চরিত্রের মিল আছে?\nক) হরিশের      খ) মামার      গ) শিক্ষকের      ঘ) বিনুর\n\n৪। উক্ত চরিত্রে প্রধান্য পেয়েছে -\ni) দৌরাত্ম্য      ii) হীনমন্যতা      iii) লোভ\nনিচের কোনটি ঠিক?\nক। i ও ii      খ। ii ও iii      গ। i ও iii      ঘ। i, ii ও iii', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.0629330575466156, t=0.6034121513366699, r=0.7733969688415527, b=0.752493143081665), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='79165e17-eea5-4dc8-8a62-6205a339ad34'),
#  Chunk(text='৫. অনুপমের বয়স কত বছর?\n\nক) পঁচিশ      খ) ছাব্বিশ      গ) সাতাশ      ঘ) আটাশ', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.06445196270942688, t=0.7577082514762878, r=0.763398289680481, b=0.8041040301322937), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='19437637-e63e-4a8d-ad2d-1c9e407b564e'),
#  Chunk(text='কতগুলো প্রশ্নের সঠিক উত্তর দিতে পারলে?\n<table><thead><tr><th>SL</th><th>Ans</th><th>SL</th><th>Ans</th><th>SL</th><th>Ans</th><th>SL</th><th>Ans</th><th>SL</th><th>Ans</th></tr></thead><tbody><tr><td>১</td><td>খ</td><td>২</td><td>গ</td><td>৩</td><td>ঘ</td><td>৪</td><td>ক</td><td>৫</td><td>গ</td></tr></tbody></table>', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.06973445415496826, t=0.8110522031784058, r=0.929538905620575, b=0.9154212474822998), image_path=None)], chunk_type=<ChunkType.table: 'table'>, chunk_id='58918858-6aa7-4382-b79b-77ff129f1cb7'),
#  Chunk(text='2', grounding=[ChunkGrounding(page=1, box=ChunkGroundingBox(l=0.4670703411102295, t=0.9211243391036987, r=0.4886101484298706, b=0.9381240606307983), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='2c68a86f-f86a-4662-9cf9-98a687917c70'),
#  Chunk(text='Summary : This is a logo for an online batch program targeting HSC 2026 students, with a focus on Bangla, English, and ICT subjects.\n\nlogo: HSC 26 Online Batch (Bangla, English, ICT)\n  Visible Text :\n    • "HSC 26" in bold white text on a red background.\n    • "অনলাইন ব্যাচ" (Online Batch in Bengali) in bold black text.\n    • "বাংলা • ইংরেজি • আইসিটি" (Bangla • English • ICT) in white text on a red background.\n  Design Elements :\n    • Red and black color scheme.\n    • Wi-Fi signal icon to the right of the main text, indicating online connectivity.\n    • Rectangular blocks for emphasis behind text.\n  Dimensions & Placement :\n    • Horizontal layout with stacked text blocks.\n    • Wi-Fi icon placed at the upper right of the main text.\n  Analysis :\n    • The logo uses bold colors and clear subject labels to target students preparing for the HSC 2026 exams, emphasizing online learning and the three core subjects.', grounding=[ChunkGrounding(page=2, box=ChunkGroundingBox(l=0.06560889631509781, t=0.02868703566491604, r=0.19877517223358154, b=0.07383497804403305), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='1f9592c4-639c-4fac-b175-cbe1e7a1e2ad'),
#  Chunk(text='logo: 10 Minute School\n\nSummary : This is the official logo of "10 Minute School", an educational platform.\n\nLogo Elements :\n  • The logo consists of the number "10" in bold black font, with the "0" partially open and featuring a red arrow curving clockwise inside it.\n  • To the right of the "10", the words "MINUTE SCHOOL" appear in uppercase black letters, stacked in two lines ("MINUTE" above "SCHOOL").\n  • The red arrow within the "0" is stylized and points to the right, suggesting movement or progress.\n  • The overall design is horizontal, with the text and number aligned on a single baseline.\n\nDimensions & Placement :\n  • The "10" is on the left, with the "MINUTE SCHOOL" text block to its right.\n  • The red arrow is contained within the "0" and does not extend outside the numeral.\n\nAnalysis :\n  • The use of a red arrow within the "0" visually emphasizes speed, direction, or progress, aligning with the brand\'s focus on quick, effective learning.\n  • The bold, modern font and simple color palette (black and red) create a professional and energetic impression.', grounding=[ChunkGrounding(page=2, box=ChunkGroundingBox(l=0.8014781475067139, t=0.03457660973072052, r=0.9319871664047241, b=0.0690053179860115), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='62642484-03ca-406f-89b3-858ca1a3659a'),
#  Chunk(text='শব্দার্থ ও টীকা\n<table><thead><tr><th>মূল শব্দ</th><th>শব্দের অর্থ ও ব্যাখ্যা</th></tr></thead><tbody><tr><td>এ জীবনটা না দৈত্যের হিসাবে বড়ো, না ওড়ের হিসাবে</td><td>গল্পের কথক চরিত্র অনুপমের আত্মসমালোচনা। পরিমাণ ও গুণ উভয় দিক দিয়েই যে তার জীবনটি নিতান্তই তুচ্ছ সে কথাই এখানে ব্যক্ত হয়েছে।</td></tr><tr><td>ফলের মতো ওটি</td><td>ওটি এক সময় পূর্ণ ফলে পরিণত হয়। কিন্তু ওটিই যদি ফলের মতো হয় তাহলে তার অসম্পূর্ণ সারবত্তা প্রকট হয়ে ওঠে। নিজের নিষ্ফল জীবনকে বোঝাতে অনুপমের ব্যবহৃত উপমা।</td></tr><tr><td>অনুপূর্ণা</td><td>অন্নে পরিপূর্ণা। দেবী দুর্গা।</td></tr><tr><td>গঞ্জানন</td><td>দেবী দুর্গার দুই পুত্র; অগ্রজ গণেশ ও অনুজ কার্তিকেয়। দুর্গার কোলে থাকা দেব-সেনাপতি কার্তিকেয়কে বোঝানো হয়েছে। ব্যঙ্গার্থে প্রয়োগ।</td></tr><tr><td>আজও আমাকে দেখিলে মনে হইবে, আমি অনুপূর্ণার কোলে গঞ্জাননের ছোটো ভাইটি।</td><td>ভয়ঙ্কর, প্রসাবন, পোত্তা। ভাষার মাধুর্য ও উৎকর্ষ বৃদ্ধি করে এমন ওপ।</td></tr><tr><td>ফন্টু</td><td>ভারতের পশ্চিম আঞ্চলের অন্তঃপুলিনা নদী। নদীটির ওপরের অঞ্চলে বালির আস্তরণ কিন্তু ভেতরে জলস্রোত প্রবাহিত।</td></tr><tr><td>ফন্টুর বালির মতন তিনি আমাদের সমস্ত সংসারটিকে নিজের অন্তরের মধ্যে প্রবিষ্ট লইয়াছেন।</td><td>অনুপম তার মামার চরিত্র-বৈশিষ্ট্য প্রসঙ্গে কথাটি বলেছে। সংসারের সমস্ত দায়-দায়িত্ব পালনে তার ভূমিকা প্রধানে টুকমার মাধ্যমে ব্যক্ত করা হয়েছে।</td></tr><tr><td>গড়ুম</td><td>একমুষ্ট বা একোশ জল</td></tr><tr><td>অন্তঃপুর</td><td>অন্দরমহল। ভেতরবাড়ি</td></tr><tr><td>স্বয়ংবরা</td><td>যে মেয়ে নিজেই স্বামী নির্বাচন করে</td></tr><tr><td>গুড়ভাতি</td><td>আলোচনা। ফর্সিং। দীর্ঘ সময়জুড়ে একাধিবেশ</td></tr><tr><td>বাঁধা ইস্কা</td><td>সাধারণ মানুষের ব্যবহার্য নারকেল-খোলে তৈরি ধূমপানের যন্ত্রবিশেষ</td></tr><tr><td>উদেপানি</td><td>প্রার্থনা। চাকরির আশায় অনেরো কাছে ধরনা দেওয়া।</td></tr><tr><td>অবকাশের রক্তবর্ণ এক কালে ইহাদের বংশে লক্ষ্মীর সম্পলচ্ছট ভরা ছিল।</td><td>আনন্দহীন প্রভুর অবসর বোঝানো হয়েছে। লক্ষ্মী ধন ও ঐশ্বর্যের দেবী। সম্পলচ্ছট তার প্রতীক। কল্যাণীদের বংশে একসময় লক্ষ্মীর কৃপায় ঐশ্বর্যের ঘট পূর্ণ ছিল।</td></tr><tr><td>পশ্চিম আঞ্চলান দ্বীপ</td><td>এখানে ভারতের পশ্চিম অঞ্চলকে বোঝানো হয়েছে।</td></tr><tr><td>কোঙ্গার</td><td>ভারতীয় সীমানাভুক্ত বন্দোপসাগরের দ্বীপবিশেষ। ফরাসি আন্দোলনের মুখে রাজবাদিদের নির্বাসন গাড়ি দিয়ে আন্দামান বা আন্দোমানে পাঠানো হতো।</td></tr></tbody></table>', grounding=[ChunkGrounding(page=2, box=ChunkGroundingBox(l=0.0675293505191803, t=0.08466562628746033, r=0.9324812889099121, b=0.9144649505615234), image_path=None)], chunk_type=<ChunkType.table: 'table'>, chunk_id='18ac78db-a8eb-4f7e-9237-4279b1be3844'),
#  Chunk(text='3', grounding=[ChunkGrounding(page=2, box=ChunkGroundingBox(l=0.4661436975002289, t=0.9201069474220276, r=0.4909071624279022, b=0.9382690787315369), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='c9abd00a-e5e2-4f78-a2e2-27eee73f46a2'),
#  Chunk(text='Summary : This image is a logo for an online educational batch named "HSC 26 অনলাইন ব্যাচ" (HSC 26 Online Batch), offering courses in Bangla, English, and ICT.\n\nlogo: HSC 26 অনলাইন ব্যাচ (Bangla, English, ICT)\n  Main Text :\n    • "HSC 26" in bold white text on a red background.\n    • "অনলাইন ব্যাচ" (Online Batch) in large black Bengali script, with a wireless signal icon to the right.\n    • "বাংলা · ইংরেজি · আইসিটি" (Bangla · English · ICT) in white text on a red background below.\n  Design & Layout :\n    • Rectangular, horizontally stacked text blocks.\n    • Red, black, and white colour scheme.\n    • Wireless signal icon suggests online/remote learning.\n  Dimensions & Placement :\n    • All text is horizontally aligned and centered.\n    • Wireless icon is placed at the upper right of the main Bengali text.\n  Analysis :\n    • The logo clearly communicates an online educational program for HSC 2026 students, focusing on Bangla, English, and ICT subjects, using bold colours and clear iconography to signal its digital/online nature.', grounding=[ChunkGrounding(page=3, box=ChunkGroundingBox(l=0.06550125032663345, t=0.02832094393670559, r=0.19898390769958496, b=0.073939248919487), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='95d93856-3fc8-4ff4-811a-04a68e294d66'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text and Design :\n  • The logo consists of the number "10" in bold black font, with the "0" partially open and containing a red arrow curving clockwise inside it.\n  • To the right of the number, the words "MINUTE SCHOOL" appear in uppercase black letters, stacked in two lines.\n  • The design is simple, with a modern sans-serif typeface and a red accent for the arrow.\n\nDimensions and Placement :\n  • The "10" is on the left, with the "MINUTE SCHOOL" text aligned to the right.\n  • The red arrow is integrated into the "0" of "10", pointing to the right and upward.\n\nAnalysis :\n  • The logo uses a red arrow to suggest speed or progress, reinforcing the "10 Minute" concept of quick learning.\n  • The clean, bold design and use of black and red create a strong, memorable brand identity.', grounding=[ChunkGrounding(page=3, box=ChunkGroundingBox(l=0.8013526201248169, t=0.03403173387050629, r=0.9322221279144287, b=0.06948012113571167), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='dfdcfad5-3e0e-40ae-930e-6cefbf17a643'),
#  Chunk(text='<table><thead><tr><th colspan="2">শব্দার্থ ও টীকা</th></tr><tr><th>মূল শব্দ</th><th>শব্দের অর্থ ও ব্যাখ্যা</th></tr></thead><tbody><tr><td>মনু-সংহীতা</td><td>বিধানকর্তা বা শাস্ত্রপ্রণেতা মুনিবিশেষ।</td></tr><tr><td>মনু-সংহীতা</td><td>মনু-প্রণীত মানুষের আচরণবিধি সংক্রান্ত গ্রন্থ ।</td></tr><tr><td>প্রজাপতি</td><td>জীবের স্রষ্টা। ব্রহ্মা। যিনি বিশ্বের দেবতা।</td></tr><tr><td>পঞ্চস্বর</td><td>সদনবেদের ব্যবহার্য পাঁচ ধরনের রাগ।</td></tr><tr><td>কন্ঠার্থ</td><td>নানা রকম বাগযন্ত্রের ঐক্যতান।</td></tr><tr><td>সেকরা</td><td>স্বর্ণকার, সোনার অলংকার প্রস্তুতকারক</td></tr><tr><td>বর্বর কোলাহলের মত হঠী দ্বারা সংগীতসরণীর পদ্ধবন দলিত বিদলিত করিয়া আমি তো বিবাহ-বাড়িতে গিয়া উঠিলাম</td><td>অনুপম নিজের বিবাহযাত্রার পরিস্থিতি বর্ণনায় সুরসুরা বিকৃত কোলাহলকে সংগীত সরণীর পদ্ধবন দলিত হওয়ার ঘটনার সঙ্গে তুলনা করছে।</td></tr><tr><td>অভিনিক্ত</td><td>অভিষেক করা হয়েছে এমন</td></tr><tr><td>সতপাদ</td><td>উপটীকা। (নোট)।</td></tr><tr><td>দেওয়া-থোওয়া</td><td>যে পাথরে ঘষে সোনার খাঁটির পরীক্ষা করা হয়</td></tr><tr><td>কপিপাত্র</td><td>আলোচনা। ফরসি। দীর্ঘ দলসুদ্ধ একাধিপত্য</td></tr><tr><td>মকরমুখো মোটা একখানা বালা</td><td>মকর বা কুমিরের মুখাকৃতিযুক্ত হাতে পরিধেয় অলংকারবিশেষ</td></tr><tr><td>এয়ারিং</td><td>কানের দুল। Earring</td></tr><tr><td>দক্ষযজ্ঞ</td><td>প্রজাপতি দক্ষ কর্তৃক অনুষ্ঠিত যজ্ঞ। এ যজ্ঞে শতিনিমন্ত্রণ ছিন্ন সতী দেহত্যাগ করেন। শ্রীর মৃত্যুসংবাদ শুনে শিব অনুচরসহ যজ্ঞস্থলে পৌঁছে যজ্ঞ ধ্বংস করে দেন এবং সতীর শব কাঁধে নিয়ে প্রলয় নৃত্য শুরু হয়। এখানে প্রলয়রবও বা হইহল্লা বোঝাচ্ছে।</td></tr><tr><td>রসনচৌকি</td><td>মালাই, চটাল ও কাঁসি- এই তিন বাদ্যযন্ত্রে সৃষ্ট একতানবাদন</td></tr><tr><td>অভ্র</td><td>এক ধরনের খনিজ ধাতু। Mica</td></tr><tr><td>অভ্রের খাড়</td><td>অভ্রের তৈরি খাড়বাটি।</td></tr><tr><td>মহানির্বাণ</td><td>সবরকমের বন্ধন থেকে মুক্তি।</td></tr><tr><td>কলি</td><td>পুরাণে বর্ণিত চার যুগের শেষ যুগ। কলিযুগ।</td></tr><tr><td>কলি যে চরপোয়া হইয়া আসিল।</td><td>কলিকাল পরিপূর্ণরূপে আত্মপ্রকাশ করল।</td></tr></tbody></table>', grounding=[ChunkGrounding(page=3, box=ChunkGroundingBox(l=0.06697314977645874, t=0.08544924855232239, r=0.9326010942459106, b=0.9148122072219849), image_path=None)], chunk_type=<ChunkType.table: 'table'>, chunk_id='222e29f0-4222-429e-ace5-082221a8a66a'),
#  Chunk(text='4', grounding=[ChunkGrounding(page=3, box=ChunkGroundingBox(l=0.4669567942619324, t=0.9205743670463562, r=0.4897192120552063, b=0.9376940131187439), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='d2e0df4d-ea60-4c71-bd19-845909c1eb48'),
#  Chunk(text='logo: HSC 26 অনলাইন ব্যাচ (Bangla, English, ICT)\nSummary : This is a logo for an online batch program targeting HSC 2026 students, with a focus on Bangla, English, and ICT subjects.\n\nMain Elements : \n  • "HSC 26" in bold white text on a red background.\n  • "অনলাইন ব্যাচ" (Online Batch in Bengali) in bold black text.\n  • Wi-Fi signal icon to the right of the main text, indicating online connectivity.\n  • "বাংলা • ইংরেজি • আইসিটি" (Bangla • English • ICT) in white text on a red background at the bottom.\n\nDesign Details : \n  • Uses a combination of red, black, and white for high contrast.\n  • All text is in Bengali except for "HSC 26".\n  • Rectangular blocks highlight key information.\n  • The Wi-Fi icon visually reinforces the online/virtual nature of the batch.\n\nDimensions & Placement : \n  • Horizontal rectangular layout.\n  • "HSC 26" and subject list are each inside red rectangles; main batch name is centered in black.\n\nAnalysis : \n  • The logo is designed to be easily recognizable for students preparing for the HSC 2026 exam, emphasizing its online format and the three core subjects offered.', grounding=[ChunkGrounding(page=4, box=ChunkGroundingBox(l=0.0658598244190216, t=0.0286154393106699, r=0.1986040472984314, b=0.07361245900392532), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='e79268a5-c8e7-4f0f-877e-2c3329a285ab'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text and Design :\n  • The logo consists of the number "10" in bold black font, with the "0" partially open and containing a red arrow curving clockwise inside it.\n  • To the right of the "10", the words "MINUTE SCHOOL" appear in uppercase black letters, stacked in two lines ("MINUTE" above "SCHOOL").\n  • The red arrow within the "0" visually suggests the concept of time or a clock, reinforcing the "minute" theme.\n\nDimensions and Placement :\n  • The "10" is on the left, with the text "MINUTE SCHOOL" aligned to the right in two lines.\n  • The logo is horizontally oriented.\n\nAnalysis :\n  • The use of a red arrow inside the "0" of "10" visually emphasizes the idea of time, aligning with the brand\'s focus on quick, time-efficient learning.\n  • The clean, modern font and simple color palette (black and red) convey professionalism and urgency.', grounding=[ChunkGrounding(page=4, box=ChunkGroundingBox(l=0.8016661405563354, t=0.03436226025223732, r=0.9318344593048096, b=0.06917835772037506), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='c6d8dc0f-d49e-41ef-90aa-df76d884034d'),
#  Chunk(text='<table><caption>শব্দার্থ ও টীকা</caption><thead><tr><th>মূল শব্দ</th><th>শব্দের অর্থ ও ব্যাখ্যা</th></tr></thead><tbody><tr><td>পাকযন্ত্র</td><td>পাকস্থলী</td></tr><tr><td>প্রদোষ</td><td>সন্ধ্যা</td></tr><tr><td>একচক্ষু লঙ্ঘন</td><td>মাটির খোলের দুপাশে চামড়া লাগানো এক ধরনের বাদ্যযন্ত্র</td></tr><tr><td>গাড়ি লোহার মুদ্দেস তাল দিতে দিতে চলিল</td><td>চলন্ত রেলগাড়ির অবিরাম ধাতব ধ্বনি বোঝানো হয়েছে</td></tr><tr><td>ধুয়া</td><td>গানের যে অংশ দোহাররা বারবার পরিবেশন করে।</td></tr><tr><td>জড়িয়া</td><td>আড়ষ্টতা। জড়ত্ব।</td></tr><tr><td>মঞ্জরী</td><td>কিশলয়যুক্ত কচি ডাল। মুকুল</td></tr><tr><td>একপতন</td><td>একপ্রস্থ</td></tr><tr><td>কানপুর</td><td>কল্যাণী যে দেশমাতৃকার সেবায় আত্মনিয়োগ করেছে, অনুপমের এই আত্মোপলব্ধি এখানে প্রকাশিত।</td></tr></tbody></table>', grounding=[ChunkGrounding(page=4, box=ChunkGroundingBox(l=0.06742861866950989, t=0.08429737389087677, r=0.9323992729187012, b=0.470933198928833), image_path=None)], chunk_type=<ChunkType.table: 'table'>, chunk_id='2ecf7217-0135-4498-ba46-fa1cc4a6a57a'),
#  Chunk(text='5', grounding=[ChunkGrounding(page=4, box=ChunkGroundingBox(l=0.46754956245422363, t=0.9196376800537109, r=0.4876352548599243, b=0.9381829500198364), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='be29a6cd-913d-4a59-82eb-352d26e7c657'),
#  Chunk(text='logo: HSC 26 অনলাইন ব্যাচ (Bangla, English, ICT)\nScene Overview : \n  • The image is a logo featuring the text "HSC 26" in a red rectangle, followed by large black Bengali text "অনলাইন ব্যাচ" (Online Batch) with a Wi-Fi signal icon, and a red bar below listing "বাংলা • ইংরেজি • আইসিটি" (Bangla • English • ICT).\n  • The design uses a combination of red, black, and white for emphasis and clarity.\nTechnical Details : \n  • All text is clear and legible, with the main title in bold fonts.\n  • No scale bar or additional UI elements are present.\nSpatial Relationships : \n  • "HSC 26" is centered at the top, "অনলাইন ব্যাচ" is the main central element, and the subject list is in a red bar at the bottom.\nAnalysis : \n  • The logo is designed to promote an online batch for HSC 2026 students, specifically for Bangla, English, and ICT subjects, using bold colors and clear text to attract attention.', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.0649322047829628, t=0.02851680852472782, r=0.1993815004825592, b=0.07441740483045578), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='c7e52e9b-051b-4e2a-aacf-c1b3ed8a206f'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text and Design :\n  • The logo consists of the number "10" in bold black font, with the "0" partially open at the top right.\n  • A red arrow curves clockwise inside the "0", forming part of the number and pointing to the right.\n  • To the right of the "10", the words "MINUTE SCHOOL" appear in uppercase black letters, stacked in two lines: "MINUTE" on top, "SCHOOL" below.\n  • The font is modern and sans-serif.\n  • The background is white.\n\nDimensions and Placement :\n  • The "10" is on the left, with the text "MINUTE SCHOOL" aligned to the right.\n  • The red arrow is integrated into the "0" of "10", making it visually distinctive.\n\nAnalysis :\n  • The logo uses a red arrow to suggest speed or progress, aligning with the "10 Minute" concept of quick learning.\n  • The clean, modern design and bold text make the brand name easily readable and memorable.', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.8007251620292664, t=0.03439099341630936, r=0.9323655962944031, b=0.06877478212118149), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='03a4364d-d6dc-4df1-90d4-405e3f63505e'),
#  Chunk(text='💡 মূল আলোচ্য বিষয়', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.0681658536195755, t=0.08591234683990479, r=0.3511078953742981, b=0.1254192590713501), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='3c0decf6-115b-45b7-a216-ddc4bf024266'),
#  Chunk(text='মূল গল্প\n\nআজ আমার বয়স সাতাশ মাত্র। এ জীবনটা না দৈর্ঘ্যের হিসাবে বড়, না গুণের হিসাবে। তবে ইহার একটু বিশেষ মূল্য আছে।ইহা সেই ফুলের মতো যাহার বুকের উপর ভ্রমর আসিয়া বসিয়াছিল, এবং সেই পদক্ষেপের ইতিহাস তাহার জীবনের মাধুর্যফলের মতো গুটি ধরিয়া উঠিয়াছে।\nসেই ইতিহাসটুকু আকারে ছোটো, তাহাকে ছোটো করিয়াই লিখিব। ছোটোকে যাঁহারা সামান্য বলিয়া ভুল করেন না তাঁহারাই ইহার রস বুঝিবেন। কলেজে যতগুলো পরীক্ষা পাশ করিবার সব আমি চুকাইয়াছি। ছেলেবেলায়', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.06785747408866882, t=0.13297760486602783, r=0.9394994974136353, b=0.2808164954185486), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='4cdcc969-f30f-4990-8ba7-27f572651404'),
#  Chunk(text='আমার সুন্দর চেহারা লইয়া পঞ্চিতমশায়\n\nআমাকে শিমুল ফুল ও মাকাল ফলের সহিত তুলনা করিয়া, বিদ্রূপ করিবার সুযোগ পাইয়াছিলেন। ইহাতে তখন বড় লজ্জা পাইতাম;', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.06776134669780731, t=0.2841709852218628, r=0.4536401033401489, b=0.3817821145057678), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='f16ca673-3c64-48fb-bb61-290fdfade9ef'),
#  Chunk(text='Summary : This image is a photograph showing a close-up of green leaves in the foreground with water droplets, while the background is blurred, featuring an indistinct figure in yellow, possibly standing near a doorway.\n\nphoto:\nScene Overview :\n  • The main subject is a cluster of green leaves with visible water droplets, sharply in focus.\n  • The background is heavily blurred (bokeh effect), showing a person or figure in yellow, possibly wearing a robe or coat, standing upright.\n  • The setting appears to be outdoors, near a structure with a doorway or dark opening.\n  • The colour palette is dominated by greens (leaves) and yellow (figure), with muted background tones.\n\nTechnical Details :\n  • No visible scale bar, text, or UI elements.\n  • Lighting appears natural, likely daylight, with highlights on the wet leaves.\n  • The image uses shallow depth of field to isolate the leaves from the background.\n\nSpatial Relationships :\n  • Leaves occupy the upper left and central foreground, with water droplets visible on their edges.\n  • The blurred figure is positioned in the background, slightly right of centre.\n  • The composition draws attention to the leaves, with the figure providing contextual depth.\n\nAnalysis :\n  • The photograph emphasizes the freshness or wetness of the leaves, possibly after rain, while the blurred figure adds narrative intrigue or a sense of presence without revealing identity or detail.\n  • The use of shallow depth of field creates a strong separation between foreground and background, focusing the viewer’s attention on the natural elements.', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.46668094396591187, t=0.28536316752433777, r=0.9314113259315491, b=0.43359485268592834), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='40b50818-948c-457e-9c54-1b9ddd993eb8'),
#  Chunk(text='কিন্তু বয়স হইল এ কথা ভাবিয়াছি, যদি  \nজন্মান্তর থাকে তবে আমার মুখে সুরূপ এবং  \nপশ্চিমদেশাদের মুখে বিদ্রূপ আবার করিয়াই প্রকাশ পায়। আমার পিতা এক কালে গরিব ছিলেন।  \nওকালতি করিয়া তিনি প্রচুর টাকা রোজগার করিয়াছেন, ভোগ করিবার সময় নিয়মমাফিক পান নাই। মৃত্যুর  \nতিন যে হাঁফ ছাড়িলেন সেই তার প্রথম অবকাশ।  \nআমার তখন বয়স অল্প। মার হাতেই আমি মানুষ। মা গরিবের ঘরের মেয়ে; তাই, আমরা যে ধনী এ কথা তিনিও  \nভোলেন না, আমাকে ভুলিতে দেন না। শৈশবকালে আমি কোল কোলেই মানুষ- বোধ করি, সেইজন্য শেষ পর্যন্ত  \nআমার পুরাপুরি বয়সই হইল না।', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.06852057576179504, t=0.38698625564575195, r=0.9381896257400513, b=0.5846057534217834), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='a0048b1b-d0e3-4517-927f-4591a06f474f'),
#  Chunk(text='আজও আমাকে দেখিলে মনে ইহবে, আমি অন্নপূর্ণার কোল গজাননের ছোটো ভাইটি।\nআমার আসল অভিভাবক আমার মাতা। তিনি আমার চেয়ে বড়োজোর বছর ছয়েক বড়। কিন্তু গঙ্গাজল বালির মতো তিনি আমাদের সমস্ত সংসারটাকে নিজের অন্তরের মধ্যে শুষিয়া নিয়াছেন। তাঁহাকে না খুঁজিয়া এখানকার এক গঙ্গাও রস পাইবার জো নাই। এই কারণে কোনো-কিছুই জন্যই আমাকে কোনো ভাবনা ভাবিতেই হয় না।কন্যার পিতা মাকেই স্বীকার করিবেন, আমি সংজ্ঞাহীন। তামাকটুকু পর্যন্ত খাইতে না। ভালোমানুষ হইবার কোনো ঝক্কি নাই, তাই আমি নিঃশঙ্ক ভালোমানুষ। মাতার আদেশ মানিয়া চলিবার ক্ষমতা আমার আছে- বুদ্ধি, না মানিবার ক্ষমতা আমার নাই। অন্নপূর্ণার শাসনে চলিবার মতো করিয়াই আমি প্রস্তুত হয়াছি, যদি কোনো কন্যা স্বয়ংবরা হন তবে এই সুলক্ষ্মণটি স্মরণ রাখিবেন।', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.06743374466896057, t=0.5884268283843994, r=0.9392069578170776, b=0.7873179912567139), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='b15505ec-f009-4ef4-b3a7-0d09eae9933c'),
#  Chunk(text='অনেক বড়ো ঘর হইতে আমার সঙ্কল্প আসিয়াছিল। কিন্তু মামা, যিনি পৃথিবীতে আমার ভাগ্যদেবতার প্রধান এজেন্ট, বিবাহ সম্পর্কে তাঁহার একটা বিশেষ মত ছিল। ধনীর কন্যা তাঁার পছন্দ নয়। আমাদের ঘরে যে মেয়ে আসিবে সে মাথা হেঁট করিয়া আসিবে, এই তিনি চান। অর্থ টাকার প্রতি আসক্তি তাঁার অস্তিমজ্জায় জড়িত।', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.06783542037010193, t=0.7909559011459351, r=0.9395362138748169, b=0.863686203956604), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='87043ecb-675b-4f66-8c5c-b132e4dffe45'),
#  Chunk(text='তিনি এমন বেহাই চান যাহার টাকা নাই অর্থ যে টাকা দিতে কসুর করিবে না। যাহাকে শোষণ করা চলিবে অর্থ বাড়িতে আসিলে গুডগুডির পরিবর্তে বাঁধা হেঁকায় তোমাক দিলে যাহার নালিশ খাটিবে না।', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.06764280796051025, t=0.8668974041938782, r=0.9392050504684448, b=0.9137400984764099), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='49f80ab8-adce-48aa-8e7b-3dba0b75d753'),
#  Chunk(text='6', grounding=[ChunkGrounding(page=5, box=ChunkGroundingBox(l=0.4670412242412567, t=0.9208555817604065, r=0.48926737904548645, b=0.9377099871635437), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='37b134dc-1f27-4a88-bf3c-4f8e5472942a'),
#  Chunk(text='Summary : This image is a logo for an online educational batch targeting HSC 2026 students, with a focus on Bangla, English, and ICT subjects.\n\nlogo: HSC 26 Online Batch (বাংলা, ইংরেজি, আইসিটি)\n\nText Elements : \n  • "HSC 26" in bold white text on a red background.\n  • "অনলাইন ব্যাচ" (Online Batch in Bengali) in bold black text.\n  • "বাংলা • ইংরেজি • আইসিটি" (Bangla • English • ICT) in white text on a red background.\n  • Wi-Fi signal icon to the right of the main text.\n\nDesign & Layout : \n  • Rectangular, horizontally oriented.\n  • Red and black colour scheme with white text for emphasis.\n  • Text is stacked in three main lines, with the Wi-Fi icon suggesting online connectivity.\n\nDimensions & Placement : \n  • All text is centered.\n  • Wi-Fi icon is placed at the upper right of the main text block.\n\nAnalysis : \n  • The logo is designed to attract students preparing for the HSC 2026 exam, highlighting the online nature of the batch and the three core subjects offered. The use of red and black creates a strong visual impact, while the Wi-Fi icon reinforces the digital/online aspect.', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.06508513540029526, t=0.028993690386414528, r=0.19951707124710083, b=0.07415444403886795), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='90b94c89-1986-4c5b-bddf-64007bcbe875'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text & Design :\n  • The logo consists of the number "10" in bold black font, with the "0" partially open at the top right and a red arrow forming part of the "0".\n  • To the right of the "10", the words "MINUTE SCHOOL" appear in uppercase black letters, stacked in two lines: "MINUTE" on top, "SCHOOL" below.\n  • The red arrow within the "0" points upward and to the right, suggesting movement or progress.\n  • The overall design is horizontal, with the text aligned to the right of the numeric element.\n\nDimensions & Placement :\n  • The "10" is larger and serves as the primary visual anchor on the left.\n  • The text "MINUTE SCHOOL" is right-aligned and occupies less vertical space than the "10".\n\nAnalysis :\n  • The logo uses a bold, modern typeface and a red accent to draw attention to the concept of quick learning ("10 minutes").\n  • The arrow motif within the "0" reinforces the idea of forward movement or advancement in education.', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.8002225160598755, t=0.03508313000202179, r=0.9325220584869385, b=0.06901706010103226), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='1b669762-cda5-4da8-a3a0-ab2d099a73f7'),
#  Chunk(text='আমার হরিশ কানপুরে কাজ করে। সে ছুটিতে কলকাতায় আসিয়া আমার মন উৎলা করিয়া দিল। সে বলিল,\n\n“ওহে, মেয়ে যদি বল একটি খাসা মেয়ে আছে।”', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.06863656640052795, t=0.09240733832120895, r=0.9359174966812134, b=0.13701942563056946), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='54a518e8-df9c-4b5d-8a61-69f1bbc3ecaa'),
#  Chunk(text="Summary : This is a photograph showing a close-up of a person writing in a notebook, with a book and other objects on a desk in the background.\n\nphoto:\nScene Overview :\n  • The main subject is a person's hand holding a pen and writing in an open notebook.\n  • The setting appears to be a desk or table, with a book standing upright and other objects (possibly a pen holder or decorative item) in the background.\n  • The perspective is from the side, focusing on the hand and notebook, with the background softly out of focus.\n  • Lighting is warm and natural, likely from a window or lamp, casting soft shadows.\n  • The colour palette is muted, with beige, brown, and cream tones dominating the scene.\n\nTechnical Details :\n  • No visible scale bar or magnification.\n  • No on-image UI elements or text are visible in the photograph itself.\n  • The book in the background has a partially visible cover, but the title is not fully legible.\n\nSpatial Relationships :\n  • The hand and notebook are in the foreground, occupying the lower left and centre of the image.\n  • The book and other desk objects are in the background, to the right and slightly behind the writing hand.\n  • The composition uses a shallow depth of field, drawing attention to the act of writing.\n\nAnalysis :\n  • The photograph visually emphasizes the act of writing or studying, with a calm and focused atmosphere.\n  • The arrangement suggests a personal or academic setting, possibly related to reading, note-taking, or journaling.", grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.06787455081939697, t=0.14228475093841553, r=0.9390034675598145, b=0.37025827169418335), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='37a6cfad-c578-4afd-ab1a-2748454014ca'),
#  Chunk(text='বকুলবনের নবপল্লববাশির মতো কাঁপিতে কাঁপিতে আলোছায়া বুনিতে লাগিল। হরিশ মানুষটা ছিল রসিক, রস দিয়ে বর্ণনা করিবার শক্তিতে তাহার ছিল, আর আমার মন ছিল তৃষার্ত।\nআমি হরিশকে বলিলাম, “একবার মামার কাছে কথাটা পড়িয়া দেখ।”\n\nহরিশ আসর জমাইতে অদ্বিতীয়া। তাই সর্ব্বাই তাহার খাতির। মামাও তাহাকে পাইলে ছাড়িতে চান না। কথাটা', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.0689946711063385, t=0.3729018568992615, r=0.9398247003555298, b=0.4705164432525635), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='f3db3717-fa17-4d6b-99a2-e97c35b782e3'),
#  Chunk(text='তাঁর বৈঠকে উঠিল। মেয়ের চেয়ে মেয়ের বাপের খবরটাই তাঁর কাছে গুরুতর। বাপের অবস্থা তিনি যেমনটি চান তেমনি।\n\nএক কালে ইহাদের বংশে লক্ষ্মীর মঙ্গলঘট ভরা ছিল। এখন তাহা শূন্য বলিলেই হয়, অথচ তলায় সামান্য কিছু বাকি আছে। দেশে বংশমর্যাদা রাখিয়া চলা সহজ নয় বলিয়া ইনি পঞ্চিতে গিয়া বাস করিতেছেন। সেখানে গরিব গৃহস্থের মতোই থাকেন। একটি মেয়ে ছাড়া তাঁর আর নাই। সুতরাং তাহারই পছন্দে লক্ষ্মীর ঘটটি একেবারে উল্টাই করিয়া দিতে দ্বিধা হইবে না।', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.06897428631782532, t=0.4746149778366089, r=0.9392231702804565, b=0.621740460395813), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='cef9cc16-a861-43fe-b6f3-912abc36a7af'),
#  Chunk(text='এসব ভালো কথা। কিন্তু, মেয়ের বয়স যে পনোরো, তাই শুনিয়া মামার মন ভার হইল। বংশে তো কোনো দোষ নাই? না, দোষ নাই- বাপ কোথাও তাঁর মেয়ের যোগ্য বর খুঁজিয়া পান না। একে তো বরের ঘাট মহার্ঘ, তাহার পরে ধুরন্ধর-ভাঁড় পণ, কাজেই বাপ কেবলই সুরবুর করিতেছেন- কিন্তু মেয়ের বয়স সুরবুর করিতেছে না।\nযাই হোক, হরিশের সরস রচনার গুণ আছে। মামার মন নরম হইল। বিবাহের ভূমিকা-অংশটা নির্বিঘ্ন সমাধা হইয়া গেল। কলকাতার বাহিরে বাকিটা যে পৃথিবীটা আছে সম্বন্ধটাকেই মামা আভাসান দ্বীপের অন্তর্গত বলিয়া জানতেন। জীবনে একবার বিশেষ কাজে তিনি কোরগাঁও পর্যন্ত গিয়াছিলেন। মামা যদি মনু হইতেন তবে তিনি হাবড়ার পুল পার হইয়াটাকে তঁাহার সংহিতায় একেবারে নিষেধ করিয়া দিতেন। মনের মধ্যে ইচ্ছা ছিল, নিজের চোখে মেয়ে দেখিয়া আসিব। সাহস করিয়া প্রচেষ্টা করিতে পারিলাম না।', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.0687662661075592, t=0.6261523365974426, r=0.9392664432525635, b=0.8241562247276306), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='cffe18bb-7ad8-4f15-997d-8acdcb8611af'),
#  Chunk(text='কন্যাকে আশীর্বাদ করিবার জন্য যাহাকে পাঠালো হইল সে আমাদের বিনুদাদা, আমার পিসতুতো ভাই। তাহার মতো কৃতী এবং দক্ষতার’ পরে আমি খোলা-আনা নির্ব্ব করিতে পারি। বিনুদা ফিরিয়া আসিয়া বলিলেন,', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.06844916939735413, t=0.8283476829528809, r=0.9384031295776367, b=0.8762131929397583), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='8b729546-9490-43d8-a417-ed3209d53622'),
#  Chunk(text='7', grounding=[ChunkGrounding(page=6, box=ChunkGroundingBox(l=0.4661222994327545, t=0.9201523065567017, r=0.4891222417354584, b=0.9373998641967773), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='db632c57-c321-4d6c-8157-676999586356'),
#  Chunk(text='Summary : This is a logo for an online educational batch targeting HSC 2026 students, with text in both English and Bengali indicating subjects covered.\n\nlogo: HSC 26 Online Batch (বাংলা, ইংরেজি, আইসিটি)\n  Visible Text & Elements :\n    • "HSC 26" in bold white text on a red background.\n    • "অনলাইন ব্যাচ" (Online Batch in Bengali) in bold black text.\n    • Wi-Fi signal icon to the right of the Bengali text.\n    • "বাংলা · ইংরেজি · আইসিটি" (Bangla · English · ICT) in white text on a red background.\n  Colour & Design :\n    • Red, black, and white colour scheme.\n    • Rectangular blocks for emphasis.\n    • Modern sans-serif font.\n  Dimensions & Placement :\n    • Horizontal layout, with English and Bengali text stacked.\n    • Wi-Fi icon placed at the upper right of the main Bengali text.\n  Analysis :\n    • The logo is designed to appeal to students preparing for the HSC 2026 exam, highlighting the online nature of the batch and the subjects offered (Bangla, English, ICT). The use of both English and Bengali ensures accessibility for a broad audience.', grounding=[ChunkGrounding(page=7, box=ChunkGroundingBox(l=0.06533429026603699, t=0.028840437531471252, r=0.19842571020126343, b=0.07446952909231186), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='f354bfe9-4a47-4f09-bd28-77c95330ffb3'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text and Design :\n  • The logo consists of the number "10" in bold black font, with the "0" partially open and containing a red arrow curving clockwise inside it.\n  • To the right of the number, the words "MINUTE SCHOOL" appear in uppercase black letters, stacked in two lines.\n  • The design is simple, with a modern sans-serif typeface and a red accent for the arrow.\n\nDimensions and Placement :\n  • The "10" is on the left, with the "MINUTE SCHOOL" text aligned to the right.\n  • The red arrow is integrated into the "0" of "10", pointing to the right.\n\nAnalysis :\n  • The logo uses a red arrow to suggest speed or progress, reinforcing the "10 Minute" concept of quick learning.\n  • The clean, bold design and use of black and red create a strong, memorable brand identity.', grounding=[ChunkGrounding(page=7, box=ChunkGroundingBox(l=0.801003634929657, t=0.03434302657842636, r=0.9318302273750305, b=0.0692453533411026), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='1a1b3be5-8bcb-4010-8d91-242996918013'),
#  Chunk(text='“মল নয় রে! খাঁটি সোনা বটে!” বিদ্যুদাদার ভাষাটা অত্যন্ত আঁটো। যেখানে আমরা বলি ‘চমৎকার’ সেখানে তিনি বলেন ‘চলনসই’। অতএব বুঝিলাম, আমার ভাগ্যে প্রজাপতির সঙ্গে পঞ্চশরের কোনো বিরোধ নাই। বলা বাহুল্য, বিবাহ-উপলক্ষে কন্যাপক্ষকেই', grounding=[ChunkGrounding(page=7, box=ChunkGroundingBox(l=0.06904703378677368, t=0.09243413805961609, r=0.9341173768043518, b=0.1592274308204651), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='882fb839-c964-4380-b536-767ba5ec92d8'),
#  Chunk(text='কলিকাতা আসিতে হইল। কন্যার পিতা শুদ্ধানাথবাবু হরিশকে কত বিশ্বাস করেন তাহার প্রমাণ এই যে, বিবাহের তিন দিন পূর্বে তিনি আমাকে চক্ষে দেখেন এবং আশীর্বাদ করিয়া যান। বয়স তাঁর চল্লিশের কিছু উপরে বা ওপারে। চুল কাঁচা, গোঁফে পাক ধরিতে আরম্ভ করিয়াছে মাত্র। সুপুরুষ বটে। ভিড়ের মধ্যে দেখিলে সকলের আগে তাঁর উপরেই চোখ পড়িবার মতো চেহারা।', grounding=[ChunkGrounding(page=7, box=ChunkGroundingBox(l=0.06897827982902527, t=0.16167756915092468, r=0.935355544090271, b=0.24840763211250305), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='3c6000d6-192a-465e-bd7a-c07097ca237d'),
#  Chunk(text='আসা করি আমাকে দেখিয়া তিনি খুবই ইম্প্রেসড। বোঝা শক্ত, কেননা তিনি বড়ই চুপচাপ। যে দুটি-একটি কথা বললেন যেন তাহাতে পুরো জোর দিয়া বললেন না। মামার মুখ তখন অনর্গল চুটিতেছিল- ধরা মনে আমাদের স্থান যে শহরের কারব চেয়ে কম নয়, সেয়েটাই তিনি নানা প্রসঙ্গে প্রচার করিতেছিলেন। শঙ্কুনাথবাবু এ কথায় একবারে গোঁসাই দিলেন না- কোনো ফাঁকও একটা বা হ্যাঁ কিছুই শোনা গেল না। আমি ইমেল দমিয়া যাইতাম, কিন্তু মামার দমালা শক্ত। তিনি শঙ্কুনাথবাবুর চুপচাপ ভাব দেখিয়া ভাবিলেন, লোকটা নিঃসন্দেহে নিভৃত, একেবারে কোনো ভেতর নাই। (বহাই-সম্প্রদায়ের আর যাই থাক, ভেতর থাকাটা দোষের, অন্তরের মামা মনে মনে খুবই ইম্প্রেসড। শঙ্কুনাথবাবু যখন উঠিলেন তখন মামা সংক্ষেপে উপরে হইতেই তাঁকে বিদায় করিলেন, গাড়িতে তুলিয়া দিতে গেলেন না।', grounding=[ChunkGrounding(page=7, box=ChunkGroundingBox(l=0.0689527690410614, t=0.24930024147033691, r=0.9342870712280273, b=0.42244791984558105), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='070b4d22-0c9d-47d6-8840-a5ce0e3ae2c1'),
#  Chunk(text='পঞ্চ সপ্তাহে দুই পক্ষে পাকাপাকি কথা ঠিক হইয়া গিয়াছিল। মামা নিজেকে অসামান্য চতুর বলিয়াই অভিমান করিয়া থাকেন। কথাবার্তায় কোথাও তিনি কিছু ফাঁক রাখেন নাই। টাকার অঙ্ক তো স্থির ছিলই, তারপরে গহনা কত ভরির এবং সোনা কত দরের হইবে সেও একেবারে বাঁধাবাঁধি হইয়া গিয়াছিল।', grounding=[ChunkGrounding(page=7, box=ChunkGroundingBox(l=0.06943467259407043, t=0.42491447925567627, r=0.9343776702880859, b=0.4904351234436035), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='6a60f41d-2da5-4422-9c44-12bbe631899c'),
#  Chunk(text='আমি নিজে এসসমস্ত কথার মধ্যে ছিলাম না; জানিতাম না দেলা-পাওয়া কি স্থির হইল। মনে জানিতাম, এই স্কুল অংশটাও বিবাহের একটা প্রধান অংশ, এবং সে অংশের ভার যার উপরে তিনি এক কড়াও ঠাকিবেন না। বস্ত্তত, আচ্ছর্দ্ধ পাকা লোক বলিয়া মায়া আমাদের সমস্ত সংসারের প্রধান গর্বের সামগ্রী। এখানে আমাদের কোনো সংরক্ষণ আছে সেখানেই সর্ব্বাই তিনি বুদ্ধির লড়াইয়ে জিতিবেন, এ একেবারে ধরা কথা, এই জন্য আমাদের অভাব না থাকিলেও এবং অন্য পক্ষে অজস্র কঠিন ইষ্টিলেও জিতিত, আমাদের সংসারের এই জেদ-ইষ্টাতে যে বাঁধুক আর যে মরুক।', grounding=[ChunkGrounding(page=7, box=ChunkGroundingBox(l=0.06945210695266724, t=0.4917168915271759, r=0.9334110617637634, b=0.6218389272689819), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='a403189f-054a-4aee-98fb-79da8f4e555a'),
# ...
#  Chunk(text='46', grounding=[ChunkGrounding(page=45, box=ChunkGroundingBox(l=0.4627956449985504, t=0.9200632572174072, r=0.4927280843257904, b=0.937949538230896), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='0951a7cf-f4d6-4dcc-a2f8-042cdd409dab'),
#  Chunk(text='logo: HSC 26 অনলাইন ব্যাচ (Bangla, English, ICT)\nScene Overview : \n  • The image is a logo featuring the text "HSC 26" in a red rectangle, "অনলাইন ব্যাচ" (Online Batch) in bold black Bengali script, and "বাংলা • ইংরেজি • আইসিটি" (Bangla • English • ICT) in a red rectangle below.\n  • There is a wireless signal icon to the right of the main text, suggesting an online or digital context.\nTechnical Details : \n  • All text is clear and legible, with a combination of Bengali and English.\n  • The design uses red, black, and white as primary colours.\nSpatial Relationships : \n  • "HSC 26" is at the top, "অনলাইন ব্যাচ" is centered in the middle, and the subject list is at the bottom.\n  • The wireless icon is positioned to the right of the main text.\nAnalysis : \n  • The logo is designed to promote an online batch for HSC 2026 students, specifically for Bangla, English, and ICT subjects, using bold colours and clear text to attract attention and convey a digital/online learning theme.', grounding=[ChunkGrounding(page=46, box=ChunkGroundingBox(l=0.06471721827983856, t=0.02869173139333725, r=0.19997547566890717, b=0.07492009550333023), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='d6cdbe09-a113-459b-9962-90d74a24e8a1'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text and Design :\n  • The logo consists of the number "10" on the left, with the "0" stylized as a circular arrow pointing to the right in red.\n  • To the right of the number, the words "MINUTE SCHOOL" are written in uppercase black letters, stacked in two lines.\n  • The font is modern and sans-serif.\n  • The red arrow within the "0" visually suggests movement or a time-related concept.\n\nDimensions and Placement :\n  • The "10" is larger and positioned to the left, with "MINUTE SCHOOL" aligned to the right in two lines.\n  • The red arrow is integrated into the "0" of "10", occupying the upper left quadrant of the circle.\n\nAnalysis :\n  • The logo uses a bold, simple design to emphasize the concept of quick learning ("10 minutes").\n  • The red arrow within the "0" reinforces the idea of time or progress, aligning with the brand\'s educational focus on efficiency.', grounding=[ChunkGrounding(page=46, box=ChunkGroundingBox(l=0.800800085067749, t=0.034763649106025696, r=0.9319033622741699, b=0.0688784196972847), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='40e95f4f-0c82-4c60-86de-85c249e05fc8'),
#  Chunk(text='শঙ্কুনাথ সেন একজোড়া কানের দুল সেকবাকে পরীক্ষা করতে বললেন। সেকরা জানায় এ দুলে সোনার পরিমাণ অনেক কম আছে। এ কানের দুল অনুপমের মামা মেয়েকে উপহার দেওয়ার সময় দিয়েছিলেন। শঙ্কুনাথ সেন অনুপমের মামার হাতে কানের দুল জোড়া দিয়ে প্রয়োজনীয় কথাটি বললেন। এ ঘটনায় অনুপমের মামা অপমানিত বোধ করেন।', grounding=[ChunkGrounding(page=46, box=ChunkGroundingBox(l=0.06936746835708618, t=0.09444455802440643, r=0.9329555630683899, b=0.1819632202386856), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='0e2f7264-55ab-4707-9954-123e9bd3b8f3'),
#  Chunk(text="৭। উপন্যাসের পত্রে 'অপরিচিতা' গল্পের অনুপম চরিত্রের বিপরীত।\n\nযথার্থ মূল্যবোধসম্পন্ন মানুষ কখনও অসঙ্গতিকে মেনে নিতে পারে না। যদি বলিষ্ঠ ব্যক্তিত্বের অধিকারী কেউ\nহন তবে তিনি নিজেকে প্রতিষ্ঠিত করতে পারেন। আর যে ব্যক্তি বলিষ্ঠ ব্যক্তিত্বের অধিকারী হতে পারে না তার\nজীবন হয় অর্থহীন ও হতাশাজনক।\nউপন্যাসের পত্রে একজন বেসরকারি চাকুরিজীবী। বাবা-মায়ের পছন্দের শিক্ষিতা সুন্দরী এক মেয়ের সঙ্গে\nবিয়ে ঠিক হয় যৌতুক নেওয়ার বিনিময়ে। সবকিছু জানার পর পত্রকে বিনিময় ছাড়া বিয়েতে রাজি হয় এবং\nতার প্রচেষ্টায় সবাই সম্মতি দেয়। অন্যদিকে 'অপরিচিতা' গল্পে অনুপম একজন ব্যক্তিত্বসম্পন্ন মানুষ। সে তার মা\nও মামার কথার বাইরে যেতে পারে না। চোখের সামনে অন্যায় হতে দেখেও প্রতিবাদ করতে পারে না। সে\nশিক্ষিত হলেও নিজের কোনো সিদ্ধান্ত নিতে পারে না, যে কারণে কল্যাণীর সঙ্গে তার বিয়ে ভেঙে যায়। এমনকি\nবিয়ের সভা থেকে অতিথেয়তা সম্পন্ন করে কল্যাণীর পিতা শশাঙ্কবাবু মেয়ের ব্যক্তিত্বহীন ছেলের কাছে\nসম্পর্কটা অসম্পূর্ণ জানান। তাই বলা যায়, উপন্যাসের পত্রে 'অপরিচিতা' গল্পের অনুপম চরিত্রের বিপরীত।", grounding=[ChunkGrounding(page=46, box=ChunkGroundingBox(l=0.06691095232963562, t=0.21467368304729462, r=0.9345436096191406, b=0.5065076351165771), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='5ebc5c14-8b00-4dac-a7c0-425808ff3069'),
#  Chunk(text="ঘ. 'অপরিচিতা' গল্পের উদ্দীপ চরিত্র যদি উপপেক্ষ চররের মতো হতো, তাহলে গল্পের পরিবৃত্তি ভিন্ন হতো। স্বাধীন মত প্রকাশের জন্য সবার আগে প্রয়োজন সাহস ও উচ্চ মানসিকতা। যাদের সেই সাহস নেই তারা সহজেই অন্যের কাছে নিজের ইচ্ছাকে বিসর্জন দেয়। চোখের সামনে অন্যায় দেখেও ইচ্ছা থাকা সত্ত্বেও তারা এর প্রতিবাদ করতে পারে না।\n'অপরিচিতা' গল্পে অনুপম শিক্ষিত হলেও একজন ব্যক্তিত্বহীন চরিত্র। সে পারিবারিকতন্ত্রের কাছে অসহায় পুতুলস্বরূপ। সে তার মা ও মামার ওপর নির্ভরশীল। গল্পের প্রথমার্ধে অনুপম চরিত্রে সীমাবদ্ধতা লক্ষ্য করা যায়। মামার মতামতের ওপর ভর করে অনুপমের বিয়ের দিন ধরা হলে যৌতুক নিয়ে নারীর চরম অবমাননাকাল মেয়ের বাবা কন্যা সম্পাদনে অসমর্থ জানালে সবকিছু দেখেও অনুপমের নীরব ভূমিকা তার ব্যক্তিত্বহীনতা প্রকাশ করে। সে অন্যায়ের প্রতিবাদ করতে পারে না বলে বিয়ের আসর থেকে অপমানিত হয়ে ফিরে আসে। অপরদিকে উপপেক্ষ চররের মতো চরিত্রে কুঁটে উঠলে অনুপমের বিপরীত চরিত্র। সে বিনিময় ছাড়াই বিয়ের পক্ষে মত দিয়ে তার ব্যক্তিত্বের বহিঃপ্রকাশ ঘটাতে সক্ষম হয়। এমনকি চররের সিদ্ধান্তই পরিবারে মেনে নেয়।\n'অপরিচিতা' গল্পের অনুপম যদি ব্যক্তিত্বসম্পন্ন যুবক হতো তাহলে কল্যাণী লক্ষ্মী হতো না এমনকি অনুপমের বিয়ের আসর থেকে ফিরে আসতে হতো না। তাই বলা যায়, 'অপরিচিতা' গল্পের উদ্দীপ চরিত্র যদি উপপেক্ষ চররের মতো হতো, তাহলে গল্পের পরিবৃত্তি ভিন্ন হতো।", grounding=[ChunkGrounding(page=46, box=ChunkGroundingBox(l=0.06618869304656982, t=0.5206112861633301, r=0.9357790946960449, b=0.8980538845062256), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='6b95e7a9-cb11-46d6-a5c6-3e97e006eb17'),
#  Chunk(text='47', grounding=[ChunkGrounding(page=46, box=ChunkGroundingBox(l=0.46205878257751465, t=0.9195546507835388, r=0.4929547905921936, b=0.9380380511283875), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='9b5eea05-6864-4e03-ad9a-80153f4779a8'),
#  Chunk(text='HSC 26\nঅনলাইন ব্যাচ\nবাংলা · ইংরেজি · আইসিটি', grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.06413745880126953, t=0.028265392407774925, r=0.20076104998588562, b=0.07548593729734421), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='5977d7d0-dcae-4fd8-8ef0-c99844a69218'),
#  Chunk(text='logo: 10 Minute School\n\nVisible Text and Design :\n  • The logo consists of the number "10" in bold black font, with the "0" partially open at the top right.\n  • A red arrow curves clockwise inside the "0", forming part of the number and pointing to the right.\n  • To the right of the number, the words "MINUTE SCHOOL" appear in uppercase black letters, stacked in two lines.\n  • The design uses a clean, sans-serif typeface and a minimalistic color palette (black and red on white).\n\nDimensions and Placement :\n  • The "10" is positioned to the left, with "MINUTE SCHOOL" aligned to the right in two lines.\n  • The red arrow is integrated into the "0" of "10", making it visually distinctive.\n\nAnalysis :\n  • The logo uses a bold, modern design to emphasize quick learning ("10 Minute") and education ("School").\n  • The red arrow suggests movement, progress, or the passage of time, reinforcing the "minute" concept.', grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.8007042407989502, t=0.034170251339673996, r=0.9323416948318481, b=0.06858235597610474), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='dbd27c9a-2774-48db-9b0f-b78be98ba2a3'),
#  Chunk(text='প্রশ্ন- ৫:\n"ধলেশ্বরী নদীর তীরে পিসিদের গ্রাম\nতার দেওরের মেয়ে\nঅভাগার সাথে তার বিবাহ ছিল ঠিকঠাক\nলক্ষ শুভ, নিস্তব্ধ প্রমাদ পাওয়া গেল-\nসেই লয়ে এসেছি পালিয়ে।\nমেয়েটা তো রক্ষা পেল\nআমি তথৈবচ\nঘরেতে এলো না সে তো, মনে তার নিত্য আসা যাওয়া\nপরনে ঢাকাই শাড়ি, কপালে সিঁদুর।"', grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.06850424408912659, t=0.09436540305614471, r=0.49897846579551697, b=0.3156057596206665), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='fa6c8808-0d3d-4052-82ce-cd3e1e25d358'),
#  Chunk(text='[সিলেট বোর্ড ২০২২]\n\nক. কল্যাণীর পিতার নাম কী?\nখ. "ঠাকুর তো আপনিই করিয়া সারিয়াছেন।"- ব্যাখ্যা কর।\nগ. অনুপমের কল্পনায় অপরিচিতার সাথে উদীপকের মেয়েটির তুলনা কর।\nঘ. \'সেই লহে এসেছি পালিয়ে\'- এ চরনের আলোকে বুদ্ধিকে বুঝিয়ে লেখ যে, উদীপকের নায়কের মতো অনুপমের বিবরের জন্য নিজের অক্ষমতাই দায়ী।', grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.06927165389060974, t=0.31249064207077026, r=0.9348093271255493, b=0.44806361198425293), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='abdd0bb2-7417-4cc8-acaf-ff95438ef792'),
#  Chunk(text='সমাধান:\n\nক. কল্যাণীর পিতার নাম শম্ভুনাথ সেন।', grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.06825204193592072, t=0.457077294588089, r=0.38856083154678345, b=0.5111939311027527), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='f03e1bb8-dc05-4c32-b9da-fd083982aacb'),
#  Chunk(text='খ. "ওটা তো আপনি\u200cই করিয়া সারিয়াছেন।"- উক্তিটি শঙ্করনাথ সেন বরের মামাকে উদ্দেশ্য করে বলেছিলেন। \'অপরিচিতা\' গল্পে কন্যাপক্ষের বিয়ের গহনা পরীক্ষা করে দেখার জন্য অনুরূপের মামা সেকরা নিয়ে বেয়েবাড়িতে উপস্থিত হন এবং গহনা পরীক্ষা করে দেখেন। মেয়ের বিয়েতে বাবা বেশি খাঁদ মেশানো সোনা দেবে বা মেয়ের বিয়ের গহনা চুরি করবে বলে যারা মনে করে তাদের কাছে মেয়ে দেওয়ার সিদ্ধান্ত থেকে সরে আসেন শঙ্করনাথ সেন। তিনি বরপক্ষকে খাওয়ানো শেষ করে বিদায় দেওয়া উপলক্ষে গাড়ি ডাকার কথা বললে বরের মামা কিছু বুঝতে না পেরে আশ্চর্য হয়ে শঙ্করনাথ বাবু ওটা করছেন কি না জানতে চান। জবাবে তিনি প্রসঙ্গ উক্তিটি করেন।', grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.0685414969921112, t=0.5297707319259644, r=0.9334664344787598, b=0.6840050220489502), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='e95f6496-3e2f-4eb0-a5a7-554997a04816'),
#  Chunk(text="গ. অনুস্ময়ের কল্পনায় অপরিচিতার সাথে উদীপকের মেয়েটির বিয়ে ভাবা সত্ত্বেও পাঠকের হৃদয়ে স্থান করে নেওয়ার বিষয়টির মিল লক্ষ্য করা যায়।\nবলিপ্র ব্যক্তি মানুষের যাপনের সৌন্দর্যের শ্রেষ্ঠতম প্রকাশ। কিন্তু ব্যক্তিহীন মানুষের স্বপ্ন একবার ভেঙে গেলে সে পুনরায় স্বপ্ন দেখতে সংহচাবোধ করে। যে কারণে সে আপন সত্তার অপমান ঘটতে না দিয়ে জীবন পলাতক হিসেবে পরিচয় বহন করে।\nউদীপকের অজগার সাথে পিপির দেওরের মেয়ের বিয়ের শুভ লক্ষ স্থির হলো। কিন্তু অজগা নিজের যোগ্যতার বিচার সাপেক্ষে মেয়ের জীবন বা ভবিষ্যৎ শঙ্কামুক্ত রাখার নিমিত্তে বিয়ের লক্ষ পালিয়ে গেল। অজগা জীবন-পলাতক হলেও সে তার পিপির দেওরের মেয়েকে হৃদয়ে ধারণ করে। অন্যদিকে 'অপরিচিতা' গল্পে কল্পনায় বিয়ে হলেও, বিয়ে হয়নি। বিয়ে না হলেও সমঝ্যুতার পাশে অনুস্ময় কল্পনাটিকে ভালোবেসে", grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.06835207343101501, t=0.6879019737243652, r=0.9342285394668579, b=0.9009110927581787), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='4051088c-eed0-4428-9e66-d516758900dd'),
#  Chunk(text='48', grounding=[ChunkGrounding(page=47, box=ChunkGroundingBox(l=0.4625781178474426, t=0.9196262955665588, r=0.4931216835975647, b=0.9381605982780457), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='0776a0a2-f0a1-4f7a-bb91-b086936bb048'),
#  Chunk(text='Summary : This image is a logo for an online batch program targeting HSC 26 students, with text in both English and Bengali indicating subjects covered.\n\nlogo: HSC 26 Online Batch (অনলাইন ব্যাচ)\n  Visible Text :\n    • "HSC 26" in bold white text on a red background.\n    • "অনলাইন ব্যাচ" (Bengali for "Online Batch") in bold black text.\n    • "বাংলা • ইংরেজি • আইসিটি" (Bengali for "Bangla • English • ICT") in white text on a red background.\n  Design Elements :\n    • Red and black color scheme.\n    • Wi-Fi signal icon to the right of the main text, indicating online connectivity.\n    • Rectangular blocks for emphasis behind key text elements.\n  Dimensions & Placement :\n    • Horizontal layout with stacked text blocks.\n    • Central alignment of all text and icons.\n  Analysis :\n    • The logo is designed to clearly communicate an online educational offering for HSC 26 students, focusing on Bangla, English, and ICT subjects, using bold colors and clear iconography to emphasize modern, digital learning.', grounding=[ChunkGrounding(page=48, box=ChunkGroundingBox(l=0.06498221307992935, t=0.02817622758448124, r=0.19957000017166138, b=0.07482446730136871), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='b0d6817a-2aa7-4f1b-88ec-a9cf6706325c'),
#  Chunk(text='Summary : This is a logo for "10 Minute School", featuring stylized text and a graphic element.\n\nlogo: 10 Minute School\n\nLogo Elements : \n  • The number "10" is displayed in bold black font.\n  • The "0" in "10" contains a red arrow curving clockwise, forming part of the zero.\n  • The words "MINUTE SCHOOL" are written in uppercase, sans-serif font, aligned to the right of the "10".\n  • "MINUTE" appears above "SCHOOL", both in black.\n\nDimensions & Placement : \n  • The "10" is on the left, with the text "MINUTE SCHOOL" stacked vertically to the right.\n  • The red arrow is positioned inside the "0", pointing to the right and upward.\n\nAnalysis : \n  • The red arrow within the "0" visually suggests the concept of time or a countdown, reinforcing the "10 Minute" theme of the brand.', grounding=[ChunkGrounding(page=48, box=ChunkGroundingBox(l=0.8010262250900269, t=0.03435886651277542, r=0.9318437576293945, b=0.06881941109895706), image_path=None)], chunk_type=<ChunkType.figure: 'figure'>, chunk_id='ace8cbd3-7553-4db8-a123-d8e55ec51f27'),
#  Chunk(text='নিজ হৃদয়ে স্থান দিয়েছে। নিজের ব্যক্তিত্বীনতাকে স্বীকার করে সারাটা জীবন কল্যাণীকে কল্পনায় রেখে জীবনের পথ অতিক্রম করেছে। বিয়ে ডেভে গেলেও উদীপকের মেয়েটি এবং কল্যাণী উভয়ই উভয়ের নির্ধারিত পাত্রের হৃদয়ে স্থান করে নিয়েছিল। তাই এ বিষয়টির মিল লক্ষ্য করা যায়।', grounding=[ChunkGrounding(page=48, box=ChunkGroundingBox(l=0.06863921880722046, t=0.09364195168018341, r=0.9324069619178772, b=0.17050255835056305), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='c28879ef-c9ee-47d6-8f15-a42189f7536e'),
#  Chunk(text="ঘ. 'সেই লক্ষ্য এসেছি পালিয়ে'- এ চরণে আলোকে উপস্থাপক নায়কের মতো অনুপমের বিয়ের জন্য নিজের অক্ষমতাই দায়ী। মজবুতী যথার্থ।\n\nসঠিক সময়ে সঠিক কাজ না করলে কখনও কাঙ্ক্ষিত লক্ষ্যে পৌঁছানো সম্ভব নয়। এজন্য কাজ সময় করতে হয়। পরিবেশ পরিস্থিতিতে নিজের যোগ্যতাকে অনুকূল আনতে না পারলে জীবনের অনুচিতচায় ভূলতে মরতে হয়।\n\n'অপরিচিতা' গল্পে অনুপমের বিয়ে ভেঙে গেলে সে বিয়ের জর্জরিত হয়। তবে অনুপম বিয়ের জন্য সে নিজেরই দায়ী। বিয়ের সভায় মেয়েকে নিয়ে গোপালবাবু সেখানে অনুপম নীরব ছিল। সে কারণে কল্যাণীর বাবা কন্যা-সম্প্রদানে অসমর্থ প্রকাশ করেন। অন্যদিকে উপস্থাপকও অগভা নিজের অযোগ্যতা অনুধাবন করতে পারে এবং বিয়া লক্ষ্য পালিয়ে যায়।\n\nউপস্থাপক অযোগ্য বিয়ের জন্য তার অক্ষমতাই দায়ী। 'অপরিচিতা' গল্পে মনস্তাপ বা বিয়েকে ভেঙে পড়া এক ব্যক্তিত্বশীল যুবকের অনুপম। তার বিয়ের জন্য সে নিজেই দায়ী, কারণ বিয়ের মূল কারণ তার অক্ষমতা। তাই বলা যায়, 'সেই লক্ষ্য এসেছি পালিয়ে'- এ চরণে আলোকে উপস্থাপক নায়কের মতো অনুপমের বিয়ের জন্য তার নিজের অক্ষমতাই যথার্থ। সুতরাং উত্তরটি যথার্থ।", grounding=[ChunkGrounding(page=48, box=ChunkGroundingBox(l=0.06597337126731873, t=0.19581769406795502, r=0.9364895820617676, b=0.5280340909957886), image_path=None)], chunk_type=<ChunkType.text: 'text'>, chunk_id='dec33b93-1f1c-4988-b633-d159fada5da5'),
#  Chunk(text='49', grounding=[ChunkGrounding(page=48, box=ChunkGroundingBox(l=0.4630049467086792, t=0.9197213053703308, r=0.49192100763320923, b=0.9379633069038391), image_path=None)], chunk_type=<ChunkType.marginalia: 'marginalia'>, chunk_id='2845a54e-b7d6-4835-8923-11bc0e60e1fd')]
